# %% [markdown]
# Trying just a cylinder first
# - go through the steps of filling the core, until you get a packed main cyl
#     - for each pebble, make the ghastly pebble object now, because you'll need it to track unique ids for recirc/dumpfile faking
# - apply velocity profile (for now, use something arbitrary)
# - get list of pebbles that are outside the core (center must be (cyl_bot+r_peb) at minimum)
# - move pebbles into 'divet' left behind
# - take coords, put them in openmc (?) jodrey-tory.
# - the above will make you lose ids - save old configuration, map each pebble to the nearest to its original location, bottom-up
# - make lammps dumpfile
# - read back into lammps, allow to settle
# - output settled coords
# - !!! next timestep get !!!

# %%
import os
import ghastly
import numpy as np
import openmc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import ghastly
#       3 import numpy as np
#       4 import openmc
#
# ModuleNotFoundError: No module named 'ghastly'
